# %%
import os
import shutil
from glob import glob

# Correct local dataset path (Windows)
dataset_path = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\CHASEDB1\CHASEDB1\CHASEDB1"

# Destination folders
images_folder = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_images"
masks_folder = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_1stHO"

# Create folders if they don't exist
os.makedirs(images_folder, exist_ok=True)
os.makedirs(masks_folder, exist_ok=True)

# Copy all images (.jpg)
images = glob(os.path.join(dataset_path, "*.jpg"))
for img in images:
    shutil.copy(img, images_folder)

# Copy only _1stHO masks
masks = glob(os.path.join(dataset_path, "*_1stHO.png"))
for mask in masks:
    shutil.copy(mask, masks_folder)

print(f"Copied {len(images)} images to {images_folder}")
print(f"Copied {len(masks)} masks to {masks_folder}")
# Out:
# Copied 28 images to C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_images
# Copied 28 masks to C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_1stHO

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import albumentations as A
import matplotlib.pyplot as plt
import random

# ================= PATHS =================
IMG_DIR = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_images"
MASK_DIR = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\processed\CHASEDB1_1stHO"

# ================= CONSTANTS =================
RESIZE_SIZE = 768  # Resize original images to 768x768
IMG_SIZE = 128     # Patch size
OVERLAP = 0.5
BATCH_SIZE = 8

# ================= AUGMENTATION =================
augmenter = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ShiftScaleRotate(
        shift_limit=0.05,
        scale_limit=0.1,
        rotate_limit=15,
        border_mode=cv2.BORDER_REFLECT,
        p=0.5
    ),
    A.RandomBrightnessContrast(p=0.3),
])

# ================= FUNCTIONS =================
def is_valid_patch(mask, threshold=0.01):
    return np.count_nonzero(mask) / mask.size > threshold

def extract_patches(img, mask, patch_size=IMG_SIZE, overlap=OVERLAP, skip_empty=True):
    stride = int(patch_size * (1 - overlap))
    patches_img = []
    patches_mask = []
    H, W = img.shape[:2]

    for y in range(0, H - patch_size + 1, stride):
        for x in range(0, W - patch_size + 1, stride):
            p_img = img[y:y+patch_size, x:x+patch_size]
            p_mask = mask[y:y+patch_size, x:x+patch_size]

            if skip_empty and not is_valid_patch(p_mask):
                continue

            patches_img.append(p_img)
            patches_mask.append(p_mask)

    return patches_img, patches_mask

def load_image_mask_paths(image_dir, mask_dir):
    image_files = sorted([
        os.path.join(image_dir, f)
        for f in os.listdir(image_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])
    mask_files = sorted([
        os.path.join(mask_dir, f)
        for f in os.listdir(mask_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])
    return image_files, mask_files

def generator(image_paths, mask_paths, augment=True, skip_empty=True):
    for img_path, mask_path in zip(image_paths, mask_paths):

        # Read images
        img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        # Resize to 768x768
        img = cv2.resize(img, (RESIZE_SIZE, RESIZE_SIZE))
        mask = cv2.resize(mask, (RESIZE_SIZE, RESIZE_SIZE))

        # Extract patches
        patches_img, patches_mask = extract_patches(
            img, mask, IMG_SIZE, OVERLAP, skip_empty
        )

        for p_img, p_mask in zip(patches_img, patches_mask):

            if augment:
                data = augmenter(image=p_img, mask=p_mask)
                p_img, p_mask = data["image"], data["mask"]

            p_img = p_img.astype(np.float32) / 255.0
            p_mask = np.expand_dims(p_mask.astype(np.float32) / 255.0, axis=-1)

            yield p_img, p_mask

# ================= LOAD PATHS =================
all_images, all_masks = load_image_mask_paths(IMG_DIR, MASK_DIR)

# ===== Manual split: FIRST 20 → train, LAST 8 → test =====
train_images = all_images[:20]
train_masks  = all_masks[:20]

test_images  = all_images[20:]
test_masks   = all_masks[20:]

print(f"Train images: {len(train_images)}")
print(f"Test images: {len(test_images)}")

# ================= TF.DATA DATASETS =================
train_ds = tf.data.Dataset.from_generator(
    lambda: generator(train_images, train_masks, augment=True, skip_empty=True),
    output_signature=(
        tf.TensorSpec((IMG_SIZE, IMG_SIZE, 3), tf.float32),
        tf.TensorSpec((IMG_SIZE, IMG_SIZE, 1), tf.float32)
    )
).shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_generator(
    lambda: generator(test_images, test_masks, augment=False, skip_empty=False),
    output_signature=(
        tf.TensorSpec((IMG_SIZE, IMG_SIZE, 3), tf.float32),
        tf.TensorSpec((IMG_SIZE, IMG_SIZE, 1), tf.float32)
    )
).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Datasets ready: train_ds, test_ds")

# ================= VISUALIZATION =================
def visualize_patches(img_path, mask_path, num_samples=6):
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # Resize for visualization
    img = cv2.resize(img, (RESIZE_SIZE, RESIZE_SIZE))
    mask = cv2.resize(mask, (RESIZE_SIZE, RESIZE_SIZE))

    patches_img, patches_mask = extract_patches(
        img, mask, patch_size=IMG_SIZE, overlap=OVERLAP, skip_empty=False
    )

    print(f"Total patches: {len(patches_img)}")

    indices = random.sample(range(len(patches_img)), min(num_samples, len(patches_img)))

    plt.figure(figsize=(12, 6))
    for i, idx in enumerate(indices):
        plt.subplot(2, num_samples, i+1)
        plt.imshow(patches_img[idx])
        plt.axis("off")

        plt.subplot(2, num_samples, i+1+num_samples)
        plt.imshow(patches_mask[idx], cmap="gray")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# Example visualization
visualize_patches(train_images[0], train_masks[0])
# Out:
# C:\Users\AUSTCSE4090\anaconda3\envs\py310\lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Train images: 20
# Test images: 8
# Datasets ready: train_ds, test_ds
# Total patches: 121

# %%
# ================= COUNT TRAINING & TEST PATCHES =================
def count_patches(image_paths, mask_paths, patch_size=IMG_SIZE, overlap=OVERLAP, skip_empty=True):
    total_patches = 0
    for img_path, mask_path in zip(image_paths, mask_paths):

        img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        patches_img, patches_mask = extract_patches(img, mask, patch_size, overlap, skip_empty)
        total_patches += len(patches_img)

    return total_patches


train_patch_count = count_patches(train_images, train_masks, skip_empty=True)
test_patch_count  = count_patches(test_images, test_masks, skip_empty=False)

print(f"Total training patches: {train_patch_count}")
print(f"Total test patches: {test_patch_count}")
# Out:
# Total training patches: 3316
# Total test patches: 1568

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def confusion_elements(y_true, y_pred):
    """Helper to calculate TP, TN, FP, FN"""
    y_pred = K.round(y_pred)
    y_true = K.round(y_true)
    TP = K.sum(y_true * y_pred)
    TN = K.sum((1 - y_true) * (1 - y_pred))
    FP = K.sum((1 - y_true) * y_pred)
    FN = K.sum(y_true * (1 - y_pred))
    return TP, TN, FP, FN

# Sensitivity (Recall)
def sensitivity(y_true, y_pred):
    TP, TN, FP, FN = confusion_elements(y_true, y_pred)
    return TP / (TP + FN + K.epsilon())

# Specificity
def specificity(y_true, y_pred):
    TP, TN, FP, FN = confusion_elements(y_true, y_pred)
    return TN / (TN + FP + K.epsilon())

# Accuracy
def accuracy(y_true, y_pred):
    TP, TN, FP, FN = confusion_elements(y_true, y_pred)
    return (TP + TN) / (TP + TN + FP + FN + K.epsilon())

# Precision
def precision(y_true, y_pred):
    TP, TN, FP, FN = confusion_elements(y_true, y_pred)
    return TP / (TP + FP + K.epsilon())

# F1-score
def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = sensitivity(y_true, y_pred)
    return 2 * ((prec * rec) / (prec + rec + K.epsilon()))

# AUC (use Keras built-in metric)
auc = tf.keras.metrics.AUC(name='auc')


import tensorflow as tf
import tensorflow.keras.backend as K

smooth = 1e-6

def iou(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(K.round(y_pred), tf.float32)  # Round to binary
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(K.round(y_pred))  # Round predictions to binary
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
from __future__ import absolute_import

from keras_unet_collection.layer_utils import *
from keras_unet_collection.activations import GELU, Snake
from keras_unet_collection._model_unet_2d import UNET_left, UNET_right
from keras_unet_collection.transformer_layers import patch_extract, patch_embedding
from keras_unet_collection._backbone_zoo import backbone_zoo, bach_norm_checker

import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, MultiHeadAttention, LayerNormalization, Dense, Embedding
    
def ViT_MLP(X, filter_num, activation='GELU', name='MLP'):
    '''
    The MLP block of ViT.
    
    ----------
    Dosovitskiy, A., Beyer, L., Kolesnikov, A., Weissenborn, D., Zhai, X., Unterthiner, 
    T., Dehghani, M., Minderer, M., Heigold, G., Gelly, S. and Uszkoreit, J., 2020. 
    An image is worth 16x16 words: Transformers for image recognition at scale. 
    arXiv preprint arXiv:2010.11929.
    
    Input
    ----------
        X: the input tensor of MLP, i.e., after MSA and skip connections
        filter_num: a list that defines the number of nodes for each MLP layer.
                        For the last MLP layer, its number of node must equal to the dimension of key.
        activation: activation of MLP nodes.
        name: prefix of the created keras layers.
        
    Output
    ----------
        V: output tensor.

    '''
    activation_func = eval(activation)
    
    for i, f in enumerate(filter_num):
        X = Dense(f, name='{}_dense_{}'.format(name, i))(X)
        X = activation_func(name='{}_activation_{}'.format(name, i))(X)
        
    return X
    
def ViT_block(V, num_heads, key_dim, filter_num_MLP, activation='GELU', name='ViT'):
    '''
    
    Vision transformer (ViT) block.
    
    ViT_block(V, num_heads, key_dim, filter_num_MLP, activation='GELU', name='ViT')
    
    ----------
    Dosovitskiy, A., Beyer, L., Kolesnikov, A., Weissenborn, D., Zhai, X., Unterthiner, 
    T., Dehghani, M., Minderer, M., Heigold, G., Gelly, S. and Uszkoreit, J., 2020. 
    An image is worth 16x16 words: Transformers for image recognition at scale. 
    arXiv preprint arXiv:2010.11929.
    
    Input
    ----------
        V: embedded input features.
        num_heads: number of attention heads.
        key_dim: dimension of the attention key (equals to the embeded dimensions).
        filter_num_MLP: a list that defines the number of nodes for each MLP layer.
                        For the last MLP layer, its number of node must equal to the dimension of key.
        activation: activation of MLP nodes.
        name: prefix of the created keras layers.
        
    Output
    ----------
        V: output tensor.
    
    '''
    # Multiheaded self-attention (MSA)
    V_atten = V # <--- skip
    V_atten = LayerNormalization(name='{}_layer_norm_1'.format(name))(V_atten)
    V_atten = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, 
                                 name='{}_atten'.format(name))(V_atten, V_atten)
    # Skip connection
    V_add = add([V_atten, V], name='{}_skip_1'.format(name)) # <--- skip
    
    # MLP
    V_MLP = V_add # <--- skip
    V_MLP = LayerNormalization(name='{}_layer_norm_2'.format(name))(V_MLP)
    V_MLP = ViT_MLP(V_MLP, filter_num_MLP, activation, name='{}_mlp'.format(name))
    # Skip connection
    V_out = add([V_MLP, V_add], name='{}_skip_2'.format(name)) # <--- skip
    
    return V_out


def transunet_2d_base(input_tensor, filter_num, stack_num_down=2, stack_num_up=2, 
                      embed_dim=768, num_mlp=3072, num_heads=12, num_transformer=12,
                      activation='ReLU', mlp_activation='GELU', batch_norm=False, pool=True, unpool=True, 
                      backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='transunet'):
    '''
    The base of transUNET with an optional ImageNet-trained backbone.
    
    ----------
    Chen, J., Lu, Y., Yu, Q., Luo, X., Adeli, E., Wang, Y., Lu, L., Yuille, A.L. and Zhou, Y., 2021. 
    Transunet: Transformers make strong encoders for medical image segmentation. arXiv preprint arXiv:2102.04306.
    
    Input
    ----------
        input_tensor: the input tensor of the base, e.g., `keras.layers.Inpyt((None, None, 3))`.
        filter_num: a list that defines the number of filters for each \
                    down- and upsampling levels. e.g., `[64, 128, 256, 512]`.
                    The depth is expected as `len(filter_num)`.
        stack_num_down: number of convolutional layers per downsampling level/block. 
        stack_num_up: number of convolutional layers (after concatenation) per upsampling level/block.
        activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interfaces, e.g., 'ReLU'.
        batch_norm: True for batch normalization.
        pool: True or 'max' for MaxPooling2D.
              'ave' for AveragePooling2D.
              False for strided conv + batch norm + activation.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.
        name: prefix of the created keras model and its layers.
        
        ---------- (keywords of ViT) ----------
        embed_dim: number of embedded dimensions.
        num_mlp: number of MLP nodes.
        num_heads: number of attention heads.
        num_transformer: number of stacked ViTs.
        mlp_activation: activation of MLP nodes.
        
        ---------- (keywords of backbone options) ----------
        backbone_name: the bakcbone model name. Should be one of the `tensorflow.keras.applications` class.
                       None (default) means no backbone. 
                       Currently supported backbones are:
                       (1) VGG16, VGG19
                       (2) ResNet50, ResNet101, ResNet152
                       (3) ResNet50V2, ResNet101V2, ResNet152V2
                       (4) DenseNet121, DenseNet169, DenseNet201
                       (5) EfficientNetB[0-7]
        weights: one of None (random initialization), 'imagenet' (pre-training on ImageNet), 
                 or the path to the weights file to be loaded.
        freeze_backbone: True for a frozen backbone.
        freeze_batch_norm: False for not freezing batch normalization layers.
        
    Output
    ----------
        X: output tensor.
    
    '''
    activation_func = eval(activation)
    
    X_skip = []
    depth_ = len(filter_num)
    
    # ----- internal parameters ----- #
    
    # patch size (fixed to 1-by-1)
    patch_size = 1
    
    # input tensor size
    input_size = input_tensor.shape[1]
    
    # encoded feature map size
    encode_size = input_size // 2**(depth_-1)
    
    # number of size-1 patches
    num_patches = encode_size ** 2 
    
    # dimension of the attention key (= dimension of embedings)
    key_dim = embed_dim
    
    # number of MLP nodes
    filter_num_MLP = [num_mlp, embed_dim]
    
    # ----- UNet-like downsampling ----- #
    
    # no backbone cases
    if backbone is None:

        X = input_tensor

        # stacked conv2d before downsampling
        X = CONV_stack(X, filter_num[0], stack_num=stack_num_down, activation=activation, 
                       batch_norm=batch_norm, name='{}_down0'.format(name))
        X_skip.append(X)

        # downsampling blocks
        for i, f in enumerate(filter_num[1:]):
            X = UNET_left(X, f, stack_num=stack_num_down, activation=activation, pool=pool, 
                          batch_norm=batch_norm, name='{}_down{}'.format(name, i+1))        
            X_skip.append(X)

    # backbone cases
    else:
        # handling VGG16 and VGG19 separately
        if 'VGG' in backbone:
            backbone_ = backbone_zoo(backbone, weights, input_tensor, depth_, freeze_backbone, freeze_batch_norm)
            # collecting backbone feature maps
            X_skip = backbone_([input_tensor,])
            depth_encode = len(X_skip)
            
        # for other backbones
        else:
            backbone_ = backbone_zoo(backbone, weights, input_tensor, depth_-1, freeze_backbone, freeze_batch_norm)
            # collecting backbone feature maps
            X_skip = backbone_([input_tensor,])
            depth_encode = len(X_skip) + 1


        # extra conv2d blocks are applied
        # if downsampling levels of a backbone < user-specified downsampling levels
        if depth_encode < depth_:

            # begins at the deepest available tensor  
            X = X_skip[-1]

            # extra downsamplings
            for i in range(depth_-depth_encode):
                i_real = i + depth_encode

                X = UNET_left(X, filter_num[i_real], stack_num=stack_num_down, activation=activation, pool=pool, 
                              batch_norm=batch_norm, name='{}_down{}'.format(name, i_real+1))
                X_skip.append(X)
        
    # subtrack the last tensor (will be replaced by the ViT output)
    X = X_skip[-1]
    X_skip = X_skip[:-1]

    # 1-by-1 linear transformation before entering ViT blocks
    X = Conv2D(filter_num[-1], 1, padding='valid', use_bias=False, name='{}_conv_trans_before'.format(name))(X)

    X = patch_extract((patch_size, patch_size))(X)
    X = patch_embedding(num_patches, embed_dim)(X)

    # stacked ViTs 
    for i in range(num_transformer):
        X = ViT_block(X, num_heads, key_dim, filter_num_MLP, activation=mlp_activation, 
                      name='{}_ViT_{}'.format(name, i))

    # reshape patches to feature maps
    X = tf.reshape(X, (-1, encode_size, encode_size, embed_dim))

    # 1-by-1 linear transformation to adjust the number of channels
    X = Conv2D(filter_num[-1], 1, padding='valid', use_bias=False, name='{}_conv_trans_after'.format(name))(X)

    X_skip.append(X)
    
    # ----- UNet-like upsampling ----- #
    
    # reverse indexing encoded feature maps
    X_skip = X_skip[::-1]
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    depth_decode = len(X_decode)

    # reverse indexing filter numbers
    filter_num_decode = filter_num[:-1][::-1]

    # upsampling with concatenation
    for i in range(depth_decode):
        X = UNET_right(X, [X_decode[i],], filter_num_decode[i], stack_num=stack_num_up, activation=activation, 
                       unpool=unpool, batch_norm=batch_norm, name='{}_up{}'.format(name, i))

    # if tensors for concatenation is not enough
    # then use upsampling without concatenation 
    if depth_decode < depth_-1:
        for i in range(depth_-depth_decode-1):
            i_real = i + depth_decode
            X = UNET_right(X, None, filter_num_decode[i_real], stack_num=stack_num_up, activation=activation, 
                       unpool=unpool, batch_norm=batch_norm, concat=False, name='{}_up{}'.format(name, i_real))
            
    return X

def transunet_2d(input_size, filter_num, n_labels, stack_num_down=2, stack_num_up=2,
                 embed_dim=768, num_mlp = 3072, num_heads=12, num_transformer=12,
                 activation='ReLU', mlp_activation='GELU', output_activation='Softmax', batch_norm=False, pool=True, unpool=True, 
                 backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='transunet'):
    '''
    TransUNET with an optional ImageNet-trained bakcbone.
    
    
    ----------
    Chen, J., Lu, Y., Yu, Q., Luo, X., Adeli, E., Wang, Y., Lu, L., Yuille, A.L. and Zhou, Y., 2021. 
    Transunet: Transformers make strong encoders for medical image segmentation. arXiv preprint arXiv:2102.04306.
    
    Input
    ----------
        input_size: the size/shape of network input, e.g., `(128, 128, 3)`.
        filter_num: a list that defines the number of filters for each \
                    down- and upsampling levels. e.g., `[64, 128, 256, 512]`.
                    The depth is expected as `len(filter_num)`.
        n_labels: number of output labels.
        stack_num_down: number of convolutional layers per downsampling level/block. 
        stack_num_up: number of convolutional layers (after concatenation) per upsampling level/block.
        activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interfaces, e.g., 'ReLU'.
        output_activation: one of the `tensorflow.keras.layers` or `keras_unet_collection.activations` interface or 'Sigmoid'.
                           Default option is 'Softmax'.
                           if None is received, then linear activation is applied.
        batch_norm: True for batch normalization.
        pool: True or 'max' for MaxPooling2D.
              'ave' for AveragePooling2D.
              False for strided conv + batch norm + activation.
        unpool: True or 'bilinear' for Upsampling2D with bilinear interpolation.
                'nearest' for Upsampling2D with nearest interpolation.
                False for Conv2DTranspose + batch norm + activation.                 
        name: prefix of the created keras model and its layers.
        
        ---------- (keywords of ViT) ----------
        embed_dim: number of embedded dimensions.
        num_mlp: number of MLP nodes.
        num_heads: number of attention heads.
        num_transformer: number of stacked ViTs.
        mlp_activation: activation of MLP nodes.
        
        ---------- (keywords of backbone options) ----------
        backbone_name: the bakcbone model name. Should be one of the `tensorflow.keras.applications` class.
                       None (default) means no backbone. 
                       Currently supported backbones are:
                       (1) VGG16, VGG19
                       (2) ResNet50, ResNet101, ResNet152
                       (3) ResNet50V2, ResNet101V2, ResNet152V2
                       (4) DenseNet121, DenseNet169, DenseNet201
                       (5) EfficientNetB[0-7]
        weights: one of None (random initialization), 'imagenet' (pre-training on ImageNet), 
                 or the path to the weights file to be loaded.
        freeze_backbone: True for a frozen backbone.
        freeze_batch_norm: False for not freezing batch normalization layers.
        
    Output
    ----------
        model: a keras model.
    
    '''
    
    activation_func = eval(activation)
        
    IN = Input(input_size)
    
    # base    
    X = transunet_2d_base(IN, filter_num, stack_num_down=stack_num_down, stack_num_up=stack_num_up, 
                          embed_dim=embed_dim, num_mlp=num_mlp, num_heads=num_heads, num_transformer=num_transformer,
                          activation=activation, mlp_activation=mlp_activation, batch_norm=batch_norm, pool=pool, unpool=unpool,
                          backbone=backbone, weights=weights, freeze_backbone=freeze_backbone, freeze_batch_norm=freeze_batch_norm, name=name)
    
    # output layer
    OUT = CONV_output(X, n_labels, kernel_size=1, activation=output_activation, name='{}_output'.format(name))
    
    # functional API model
    model = Model(inputs=[IN,], outputs=[OUT,], name='{}_model'.format(name))
    
    return model

# %%
# Define input size, filter_num, and other parameters
input_size = (128, 128, 3)  # example input size
filter_num = [64, 128, 256, 512]  # example filter sizes
n_labels = 1  # binary segmentation, so only 1 output class (foreground vs background)

# Create the TransUNet model for binary segmentation
model = transunet_2d(input_size=input_size, filter_num=filter_num, n_labels=n_labels,
                     stack_num_down=2, stack_num_up=2, embed_dim=768, num_mlp=3072,
                     num_heads=12, num_transformer=12, activation='ReLU', mlp_activation='GELU',
                     output_activation='Sigmoid', batch_norm=False, pool=True, unpool=True, 
                     backbone=None, weights='imagenet', freeze_backbone=True, freeze_batch_norm=True, name='transunet')

# Now call summary on the created model
model.summary()
# Out:
# Model: "transunet_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  transunet_down0_0 (Conv2D)     (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  transunet_down0_0_activation (  (None, 128, 128, 64  0          ['transunet_down0_0[0][0]']
#  ReLU)                          )
#
#  transunet_down0_1 (Conv2D)     (None, 128, 128, 64  36928       ['transunet_down0_0_activation[0]
#                                 )                                [0]']
#
#  transunet_down0_1_activation (  (None, 128, 128, 64  0          ['transunet_down0_1[0][0]']
#  ReLU)                          )
#
#  transunet_down1_encode_maxpool  (None, 64, 64, 64)  0           ['transunet_down0_1_activation[0]
#   (MaxPooling2D)                                                 [0]']
#
#  transunet_down1_conv_0 (Conv2D  (None, 64, 64, 128)  73856      ['transunet_down1_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down1_conv_0_activat  (None, 64, 64, 128)  0          ['transunet_down1_conv_0[0][0]']
#  ion (ReLU)
#
#  transunet_down1_conv_1 (Conv2D  (None, 64, 64, 128)  147584     ['transunet_down1_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down1_conv_1_activat  (None, 64, 64, 128)  0          ['transunet_down1_conv_1[0][0]']
#  ion (ReLU)
#
#  transunet_down2_encode_maxpool  (None, 32, 32, 128)  0          ['transunet_down1_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  transunet_down2_conv_0 (Conv2D  (None, 32, 32, 256)  295168     ['transunet_down2_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down2_conv_0_activat  (None, 32, 32, 256)  0          ['transunet_down2_conv_0[0][0]']
#  ion (ReLU)
#
#  transunet_down2_conv_1 (Conv2D  (None, 32, 32, 256)  590080     ['transunet_down2_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down2_conv_1_activat  (None, 32, 32, 256)  0          ['transunet_down2_conv_1[0][0]']
#  ion (ReLU)
#
#  transunet_down3_encode_maxpool  (None, 16, 16, 256)  0          ['transunet_down2_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  transunet_down3_conv_0 (Conv2D  (None, 16, 16, 512)  1180160    ['transunet_down3_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down3_conv_0_activat  (None, 16, 16, 512)  0          ['transunet_down3_conv_0[0][0]']
#  ion (ReLU)
#
#  transunet_down3_conv_1 (Conv2D  (None, 16, 16, 512)  2359808    ['transunet_down3_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down3_conv_1_activat  (None, 16, 16, 512)  0          ['transunet_down3_conv_1[0][0]']
#  ion (ReLU)
#
#  transunet_conv_trans_before (C  (None, 16, 16, 512)  262144     ['transunet_down3_conv_1_activati
#  onv2D)                                                          on[0][0]']
#
#  patch_extract (patch_extract)  (None, 256, 512)     0           ['transunet_conv_trans_before[0][
#                                                                  0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 768)    590592      ['patch_extract[0][0]']
#  ng)
#
#  transunet_ViT_0_layer_norm_1 (  (None, 256, 768)    1536        ['patch_embedding[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_0_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_0_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_0_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_0_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_0_atten[0][0]',
#                                                                   'patch_embedding[0][0]']
#
#  transunet_ViT_0_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_0_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_0_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_0_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_0_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_0_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_0_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_0_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_0_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_0_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_0_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_0_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_0_skip_1[0][0]']
#
#  transunet_ViT_1_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_0_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_1_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_1_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_1_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_1_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_1_atten[0][0]',
#                                                                   'transunet_ViT_0_skip_2[0][0]']
#
#  transunet_ViT_1_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_1_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_1_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_1_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_1_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_1_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_1_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_1_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_1_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_1_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_1_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_1_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_1_skip_1[0][0]']
#
#  transunet_ViT_2_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_1_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_2_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_2_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_2_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_2_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_2_atten[0][0]',
#                                                                   'transunet_ViT_1_skip_2[0][0]']
#
#  transunet_ViT_2_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_2_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_2_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_2_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_2_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_2_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_2_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_2_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_2_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_2_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_2_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_2_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_2_skip_1[0][0]']
#
#  transunet_ViT_3_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_2_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_3_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_3_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_3_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_3_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_3_atten[0][0]',
#                                                                   'transunet_ViT_2_skip_2[0][0]']
#
#  transunet_ViT_3_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_3_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_3_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_3_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_3_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_3_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_3_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_3_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_3_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_3_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_3_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_3_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_3_skip_1[0][0]']
#
#  transunet_ViT_4_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_3_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_4_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_4_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_4_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_4_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_4_atten[0][0]',
#                                                                   'transunet_ViT_3_skip_2[0][0]']
#
#  transunet_ViT_4_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_4_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_4_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_4_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_4_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_4_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_4_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_4_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_4_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_4_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_4_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_4_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_4_skip_1[0][0]']
#
#  transunet_ViT_5_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_4_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_5_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_5_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_5_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_5_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_5_atten[0][0]',
#                                                                   'transunet_ViT_4_skip_2[0][0]']
#
#  transunet_ViT_5_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_5_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_5_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_5_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_5_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_5_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_5_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_5_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_5_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_5_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_5_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_5_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_5_skip_1[0][0]']
#
#  transunet_ViT_6_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_5_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_6_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_6_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_6_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_6_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_6_atten[0][0]',
#                                                                   'transunet_ViT_5_skip_2[0][0]']
#
#  transunet_ViT_6_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_6_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_6_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_6_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_6_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_6_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_6_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_6_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_6_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_6_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_6_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_6_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_6_skip_1[0][0]']
#
#  transunet_ViT_7_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_6_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_7_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_7_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_7_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_7_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_7_atten[0][0]',
#                                                                   'transunet_ViT_6_skip_2[0][0]']
#
#  transunet_ViT_7_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_7_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_7_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_7_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_7_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_7_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_7_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_7_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_7_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_7_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_7_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_7_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_7_skip_1[0][0]']
#
#  transunet_ViT_8_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_7_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_8_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_8_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_8_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_8_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_8_atten[0][0]',
#                                                                   'transunet_ViT_7_skip_2[0][0]']
#
#  transunet_ViT_8_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_8_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_8_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_8_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_8_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_8_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_8_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_8_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_8_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_8_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_8_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_8_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_8_skip_1[0][0]']
#
#  transunet_ViT_9_layer_norm_1 (  (None, 256, 768)    1536        ['transunet_ViT_8_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_9_atten (MultiHe  (None, 256, 768)    28339968    ['transunet_ViT_9_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_9_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_9_skip_1 (Add)   (None, 256, 768)     0           ['transunet_ViT_9_atten[0][0]',
#                                                                   'transunet_ViT_8_skip_2[0][0]']
#
#  transunet_ViT_9_layer_norm_2 (  (None, 256, 768)    1536        ['transunet_ViT_9_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_9_mlp_dense_0 (D  (None, 256, 3072)   2362368     ['transunet_ViT_9_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_9_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_9_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_9_mlp_dense_1 (D  (None, 256, 768)    2360064     ['transunet_ViT_9_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_9_mlp_activation  (None, 256, 768)    0           ['transunet_ViT_9_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_9_skip_2 (Add)   (None, 256, 768)     0           ['transunet_ViT_9_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_9_skip_1[0][0]']
#
#  transunet_ViT_10_layer_norm_1   (None, 256, 768)    1536        ['transunet_ViT_9_skip_2[0][0]']
#  (LayerNormalization)
#
#  transunet_ViT_10_atten (MultiH  (None, 256, 768)    28339968    ['transunet_ViT_10_layer_norm_1[0
#  eadAttention)                                                   ][0]',
#                                                                   'transunet_ViT_10_layer_norm_1[0
#                                                                  ][0]']
#
#  transunet_ViT_10_skip_1 (Add)  (None, 256, 768)     0           ['transunet_ViT_10_atten[0][0]',
#                                                                   'transunet_ViT_9_skip_2[0][0]']
#
#  transunet_ViT_10_layer_norm_2   (None, 256, 768)    1536        ['transunet_ViT_10_skip_1[0][0]']
#  (LayerNormalization)
#
#  transunet_ViT_10_mlp_dense_0 (  (None, 256, 3072)   2362368     ['transunet_ViT_10_layer_norm_2[0
#  Dense)                                                          ][0]']
#
#  transunet_ViT_10_mlp_activatio  (None, 256, 3072)   0           ['transunet_ViT_10_mlp_dense_0[0]
#  n_0 (GELU)                                                      [0]']
#
#  transunet_ViT_10_mlp_dense_1 (  (None, 256, 768)    2360064     ['transunet_ViT_10_mlp_activation
#  Dense)                                                          _0[0][0]']
#
#  transunet_ViT_10_mlp_activatio  (None, 256, 768)    0           ['transunet_ViT_10_mlp_dense_1[0]
#  n_1 (GELU)                                                      [0]']
#
#  transunet_ViT_10_skip_2 (Add)  (None, 256, 768)     0           ['transunet_ViT_10_mlp_activation
#                                                                  _1[0][0]',
#                                                                   'transunet_ViT_10_skip_1[0][0]']
#
#  transunet_ViT_11_layer_norm_1   (None, 256, 768)    1536        ['transunet_ViT_10_skip_2[0][0]']
#  (LayerNormalization)
#
#  transunet_ViT_11_atten (MultiH  (None, 256, 768)    28339968    ['transunet_ViT_11_layer_norm_1[0
#  eadAttention)                                                   ][0]',
#                                                                   'transunet_ViT_11_layer_norm_1[0
#                                                                  ][0]']
#
#  transunet_ViT_11_skip_1 (Add)  (None, 256, 768)     0           ['transunet_ViT_11_atten[0][0]',
#                                                                   'transunet_ViT_10_skip_2[0][0]']
#
#  transunet_ViT_11_layer_norm_2   (None, 256, 768)    1536        ['transunet_ViT_11_skip_1[0][0]']
#  (LayerNormalization)
#
#  transunet_ViT_11_mlp_dense_0 (  (None, 256, 3072)   2362368     ['transunet_ViT_11_layer_norm_2[0
#  Dense)                                                          ][0]']
#
#  transunet_ViT_11_mlp_activatio  (None, 256, 3072)   0           ['transunet_ViT_11_mlp_dense_0[0]
#  n_0 (GELU)                                                      [0]']
#
#  transunet_ViT_11_mlp_dense_1 (  (None, 256, 768)    2360064     ['transunet_ViT_11_mlp_activation
#  Dense)                                                          _0[0][0]']
#
#  transunet_ViT_11_mlp_activatio  (None, 256, 768)    0           ['transunet_ViT_11_mlp_dense_1[0]
#  n_1 (GELU)                                                      [0]']
#
#  transunet_ViT_11_skip_2 (Add)  (None, 256, 768)     0           ['transunet_ViT_11_mlp_activation
#                                                                  _1[0][0]',
#                                                                   'transunet_ViT_11_skip_1[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 16, 16, 768)  0           ['transunet_ViT_11_skip_2[0][0]']
#
#  transunet_conv_trans_after (Co  (None, 16, 16, 512)  393216     ['tf.reshape[0][0]']
#  nv2D)
#
#  transunet_up0_decode_unpool (U  (None, 32, 32, 512)  0          ['transunet_conv_trans_after[0][0
#  pSampling2D)                                                    ]']
#
#  transunet_up0_conv_before_conc  (None, 32, 32, 256)  1179904    ['transunet_up0_decode_unpool[0][
#  at_0 (Conv2D)                                                   0]']
#
#  transunet_up0_conv_before_conc  (None, 32, 32, 256)  0          ['transunet_up0_conv_before_conca
#  at_0_activation (ReLU)                                          t_0[0][0]']
#
#  transunet_up0_concat (Concaten  (None, 32, 32, 512)  0          ['transunet_up0_conv_before_conca
#  ate)                                                            t_0_activation[0][0]',
#                                                                   'transunet_down2_conv_1_activati
#                                                                  on[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  1179904    ['transunet_up0_concat[0][0]']
#  t_0 (Conv2D)
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  0          ['transunet_up0_conv_after_concat
#  t_0_activation (ReLU)                                           _0[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  590080     ['transunet_up0_conv_after_concat
#  t_1 (Conv2D)                                                    _0_activation[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  0          ['transunet_up0_conv_after_concat
#  t_1_activation (ReLU)                                           _1[0][0]']
#
#  transunet_up1_decode_unpool (U  (None, 64, 64, 256)  0          ['transunet_up0_conv_after_concat
#  pSampling2D)                                                    _1_activation[0][0]']
#
#  transunet_up1_conv_before_conc  (None, 64, 64, 128)  295040     ['transunet_up1_decode_unpool[0][
#  at_0 (Conv2D)                                                   0]']
#
#  transunet_up1_conv_before_conc  (None, 64, 64, 128)  0          ['transunet_up1_conv_before_conca
#  at_0_activation (ReLU)                                          t_0[0][0]']
#
#  transunet_up1_concat (Concaten  (None, 64, 64, 256)  0          ['transunet_up1_conv_before_conca
#  ate)                                                            t_0_activation[0][0]',
#                                                                   'transunet_down1_conv_1_activati
#                                                                  on[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  295040     ['transunet_up1_concat[0][0]']
#  t_0 (Conv2D)
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  0          ['transunet_up1_conv_after_concat
#  t_0_activation (ReLU)                                           _0[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  147584     ['transunet_up1_conv_after_concat
#  t_1 (Conv2D)                                                    _0_activation[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  0          ['transunet_up1_conv_after_concat
#  t_1_activation (ReLU)                                           _1[0][0]']
#
#  transunet_up2_decode_unpool (U  (None, 128, 128, 12  0          ['transunet_up1_conv_after_concat
#  pSampling2D)                   8)                               _1_activation[0][0]']
#
#  transunet_up2_conv_before_conc  (None, 128, 128, 64  73792      ['transunet_up2_decode_unpool[0][
#  at_0 (Conv2D)                  )                                0]']
#
#  transunet_up2_conv_before_conc  (None, 128, 128, 64  0          ['transunet_up2_conv_before_conca
#  at_0_activation (ReLU)         )                                t_0[0][0]']
#
#  transunet_up2_concat (Concaten  (None, 128, 128, 12  0          ['transunet_up2_conv_before_conca
#  ate)                           8)                               t_0_activation[0][0]',
#                                                                   'transunet_down0_1_activation[0]
#                                                                  [0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  73792      ['transunet_up2_concat[0][0]']
#  t_0 (Conv2D)                   )
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  0          ['transunet_up2_conv_after_concat
#  t_0_activation (ReLU)          )                                _0[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  36928      ['transunet_up2_conv_after_concat
#  t_1 (Conv2D)                   )                                _0_activation[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  0          ['transunet_up2_conv_after_concat
#  t_1_activation (ReLU)          )                                _1[0][0]']
#
#  transunet_output (Conv2D)      (None, 128, 128, 1)  65          ['transunet_up2_conv_after_concat
#                                                                  _1_activation[0][0]']
#
#  transunet_output_activation (A  (None, 128, 128, 1)  0          ['transunet_output[0][0]']
#  ctivation)
#
# ==================================================================================================
# Total params: 406,589,121
# Trainable params: 406,589,121
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# ----------------------------------
# Tversky Index
# ----------------------------------
def tversky(y_true, y_pred, alpha=0.7, beta=0.3):
    # numerical stability
    y_pred = K.clip(y_pred, 1e-7, 1 - 1e-7)

    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    

    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)

    return (true_pos + 1e-6) / (
        true_pos + alpha * false_neg + beta * false_pos + 1e-6
    )


# ----------------------------------
# Focal Tversky Loss
# ----------------------------------
def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return K.pow((1 - tv), gamma)


# ----------------------------------
# Hybrid Loss (Recommended)
# ----------------------------------
def hybrid_loss(y_true, y_pred):
    ft = focal_tversky_loss(y_true, y_pred)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    return 0.7 * ft + 0.3 * bce

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import Adam


# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)


def lr_schedule(epoch, lr):
    if epoch < 5:  # Warmup phase
        return lr * 1.5  # Increase LR to stabilize training
    elif epoch < 30:
        return lr * 0.98  # Gradual decay
    else:
        return lr * 0.95  # Final stabilization

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
from tensorflow.keras.losses import BinaryCrossentropy
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    lr_scheduler
    #tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]



# Compile the model
model.compile(
    optimizer=optimizer,
    loss= hybrid_loss,  # Use BCE loss for binary segmentation
    metrics=[sensitivity, specificity, accuracy, f1_score, auc,dice_coef,iou]  # Your custom metrics
)


# Fit the model
history = model.fit(
    train_ds,
    #validation_data=test_ds,
     # optional if dataset is finite
    epochs=80,
)
# Out:
# Epoch 1/80
# 274/274 [==============================] - 67s 190ms/step - loss: 0.7288 - sensitivity: 0.0109 - specificity: 0.9909 - accuracy: 0.9011 - f1_score: 0.0065 - auc: 0.5476 - dice_coef: 0.0065 - iou: 0.0036
# Epoch 2/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.6902 - sensitivity: 0.1208 - specificity: 0.9601 - accuracy: 0.8829 - f1_score: 0.1267 - auc: 0.6771 - dice_coef: 0.1264 - iou: 0.0725
# Epoch 3/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.6298 - sensitivity: 0.3124 - specificity: 0.9416 - accuracy: 0.8850 - f1_score: 0.3147 - auc: 0.7596 - dice_coef: 0.3137 - iou: 0.1971
# Epoch 4/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.5175 - sensitivity: 0.5363 - specificity: 0.9486 - accuracy: 0.9125 - f1_score: 0.5248 - auc: 0.8387 - dice_coef: 0.5229 - iou: 0.3626
# Epoch 5/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.4403 - sensitivity: 0.6412 - specificity: 0.9562 - accuracy: 0.9282 - f1_score: 0.6173 - auc: 0.8858 - dice_coef: 0.6149 - iou: 0.4487
# Epoch 6/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.4290 - sensitivity: 0.6601 - specificity: 0.9544 - accuracy: 0.9281 - f1_score: 0.6243 - auc: 0.8894 - dice_coef: 0.6220 - iou: 0.4554
# Epoch 7/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.4058 - sensitivity: 0.6926 - specificity: 0.9539 - accuracy: 0.9307 - f1_score: 0.6458 - auc: 0.9015 - dice_coef: 0.6433 - iou: 0.4776
# Epoch 8/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.3930 - sensitivity: 0.7145 - specificity: 0.9525 - accuracy: 0.9318 - f1_score: 0.6553 - auc: 0.9089 - dice_coef: 0.6528 - iou: 0.4885
# Epoch 9/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.3942 - sensitivity: 0.7096 - specificity: 0.9522 - accuracy: 0.9310 - f1_score: 0.6522 - auc: 0.9078 - dice_coef: 0.6498 - iou: 0.4843
# Epoch 10/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.3779 - sensitivity: 0.7331 - specificity: 0.9528 - accuracy: 0.9335 - f1_score: 0.6675 - auc: 0.9165 - dice_coef: 0.6650 - iou: 0.5016
# Epoch 11/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.3658 - sensitivity: 0.7438 - specificity: 0.9546 - accuracy: 0.9360 - f1_score: 0.6776 - auc: 0.9232 - dice_coef: 0.6750 - iou: 0.5119
# Epoch 12/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.3606 - sensitivity: 0.7478 - specificity: 0.9558 - accuracy: 0.9378 - f1_score: 0.6820 - auc: 0.9244 - dice_coef: 0.6794 - iou: 0.5173
# Epoch 13/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.3575 - sensitivity: 0.7518 - specificity: 0.9551 - accuracy: 0.9376 - f1_score: 0.6858 - auc: 0.9258 - dice_coef: 0.6832 - iou: 0.5214
# Epoch 14/80
# 274/274 [==============================] - 52s 186ms/step - loss: 0.3486 - sensitivity: 0.7614 - specificity: 0.9565 - accuracy: 0.9394 - f1_score: 0.6946 - auc: 0.9286 - dice_coef: 0.6919 - iou: 0.5312
# Epoch 15/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.3409 - sensitivity: 0.7704 - specificity: 0.9572 - accuracy: 0.9406 - f1_score: 0.7024 - auc: 0.9314 - dice_coef: 0.6998 - iou: 0.5404
# Epoch 16/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.3345 - sensitivity: 0.7763 - specificity: 0.9583 - accuracy: 0.9422 - f1_score: 0.7081 - auc: 0.9336 - dice_coef: 0.7053 - iou: 0.5471
# Epoch 17/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.3269 - sensitivity: 0.7870 - specificity: 0.9587 - accuracy: 0.9435 - f1_score: 0.7144 - auc: 0.9368 - dice_coef: 0.7117 - iou: 0.5546
# Epoch 18/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.3232 - sensitivity: 0.7888 - specificity: 0.9595 - accuracy: 0.9446 - f1_score: 0.7188 - auc: 0.9388 - dice_coef: 0.7159 - iou: 0.5600
# Epoch 19/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.3185 - sensitivity: 0.7945 - specificity: 0.9602 - accuracy: 0.9456 - f1_score: 0.7240 - auc: 0.9395 - dice_coef: 0.7210 - iou: 0.5658
# Epoch 20/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.3144 - sensitivity: 0.8002 - specificity: 0.9602 - accuracy: 0.9460 - f1_score: 0.7281 - auc: 0.9414 - dice_coef: 0.7252 - iou: 0.5706
# Epoch 21/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.3071 - sensitivity: 0.8083 - specificity: 0.9609 - accuracy: 0.9475 - f1_score: 0.7347 - auc: 0.9437 - dice_coef: 0.7318 - iou: 0.5788
# Epoch 22/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.3020 - sensitivity: 0.8130 - specificity: 0.9616 - accuracy: 0.9486 - f1_score: 0.7395 - auc: 0.9460 - dice_coef: 0.7365 - iou: 0.5847
# Epoch 23/80
# 274/274 [==============================] - 52s 187ms/step - loss: 0.2982 - sensitivity: 0.8180 - specificity: 0.9620 - accuracy: 0.9493 - f1_score: 0.7439 - auc: 0.9465 - dice_coef: 0.7409 - iou: 0.5901
# Epoch 24/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2927 - sensitivity: 0.8231 - specificity: 0.9627 - accuracy: 0.9504 - f1_score: 0.7491 - auc: 0.9486 - dice_coef: 0.7460 - iou: 0.5966
# Epoch 25/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2938 - sensitivity: 0.8222 - specificity: 0.9624 - accuracy: 0.9501 - f1_score: 0.7475 - auc: 0.9485 - dice_coef: 0.7443 - iou: 0.5947
# Epoch 26/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2878 - sensitivity: 0.8281 - specificity: 0.9632 - accuracy: 0.9514 - f1_score: 0.7529 - auc: 0.9506 - dice_coef: 0.7497 - iou: 0.6014
# Epoch 27/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2842 - sensitivity: 0.8312 - specificity: 0.9639 - accuracy: 0.9522 - f1_score: 0.7568 - auc: 0.9511 - dice_coef: 0.7535 - iou: 0.6064
# Epoch 28/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2815 - sensitivity: 0.8337 - specificity: 0.9643 - accuracy: 0.9529 - f1_score: 0.7598 - auc: 0.9513 - dice_coef: 0.7565 - iou: 0.6099
# Epoch 29/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2788 - sensitivity: 0.8362 - specificity: 0.9644 - accuracy: 0.9532 - f1_score: 0.7623 - auc: 0.9527 - dice_coef: 0.7589 - iou: 0.6131
# Epoch 30/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2740 - sensitivity: 0.8407 - specificity: 0.9651 - accuracy: 0.9542 - f1_score: 0.7677 - auc: 0.9537 - dice_coef: 0.7642 - iou: 0.6198
# Epoch 31/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2739 - sensitivity: 0.8407 - specificity: 0.9653 - accuracy: 0.9544 - f1_score: 0.7675 - auc: 0.9537 - dice_coef: 0.7640 - iou: 0.6197
# Epoch 32/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2714 - sensitivity: 0.8431 - specificity: 0.9656 - accuracy: 0.9548 - f1_score: 0.7706 - auc: 0.9544 - dice_coef: 0.7670 - iou: 0.6237
# Epoch 33/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2666 - sensitivity: 0.8464 - specificity: 0.9666 - accuracy: 0.9560 - f1_score: 0.7751 - auc: 0.9560 - dice_coef: 0.7714 - iou: 0.6294
# Epoch 34/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2666 - sensitivity: 0.8465 - specificity: 0.9664 - accuracy: 0.9559 - f1_score: 0.7756 - auc: 0.9560 - dice_coef: 0.7718 - iou: 0.6300
# Epoch 35/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2627 - sensitivity: 0.8508 - specificity: 0.9669 - accuracy: 0.9566 - f1_score: 0.7791 - auc: 0.9569 - dice_coef: 0.7753 - iou: 0.6344
# Epoch 36/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2597 - sensitivity: 0.8529 - specificity: 0.9675 - accuracy: 0.9574 - f1_score: 0.7823 - auc: 0.9575 - dice_coef: 0.7784 - iou: 0.6386
# Epoch 37/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2572 - sensitivity: 0.8561 - specificity: 0.9677 - accuracy: 0.9579 - f1_score: 0.7843 - auc: 0.9583 - dice_coef: 0.7803 - iou: 0.6411
# Epoch 38/80
# 274/274 [==============================] - 53s 188ms/step - loss: 0.2574 - sensitivity: 0.8547 - specificity: 0.9677 - accuracy: 0.9578 - f1_score: 0.7845 - auc: 0.9585 - dice_coef: 0.7807 - iou: 0.6415
# Epoch 39/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2538 - sensitivity: 0.8588 - specificity: 0.9680 - accuracy: 0.9586 - f1_score: 0.7878 - auc: 0.9603 - dice_coef: 0.7838 - iou: 0.6459
# Epoch 40/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2543 - sensitivity: 0.8575 - specificity: 0.9680 - accuracy: 0.9585 - f1_score: 0.7871 - auc: 0.9598 - dice_coef: 0.7831 - iou: 0.6449
# Epoch 41/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2522 - sensitivity: 0.8600 - specificity: 0.9683 - accuracy: 0.9589 - f1_score: 0.7896 - auc: 0.9595 - dice_coef: 0.7856 - iou: 0.6480
# Epoch 42/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2522 - sensitivity: 0.8590 - specificity: 0.9687 - accuracy: 0.9590 - f1_score: 0.7899 - auc: 0.9596 - dice_coef: 0.7859 - iou: 0.6485
# Epoch 43/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2521 - sensitivity: 0.8593 - specificity: 0.9686 - accuracy: 0.9592 - f1_score: 0.7895 - auc: 0.9599 - dice_coef: 0.7854 - iou: 0.6482
# Epoch 44/80
# 274/274 [==============================] - 53s 189ms/step - loss: 0.2503 - sensitivity: 0.8624 - specificity: 0.9684 - accuracy: 0.9591 - f1_score: 0.7915 - auc: 0.9605 - dice_coef: 0.7874 - iou: 0.6506
# Epoch 45/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2473 - sensitivity: 0.8641 - specificity: 0.9691 - accuracy: 0.9599 - f1_score: 0.7946 - auc: 0.9612 - dice_coef: 0.7903 - iou: 0.6546
# Epoch 46/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2439 - sensitivity: 0.8678 - specificity: 0.9696 - accuracy: 0.9607 - f1_score: 0.7977 - auc: 0.9617 - dice_coef: 0.7934 - iou: 0.6589
# Epoch 47/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2435 - sensitivity: 0.8683 - specificity: 0.9697 - accuracy: 0.9607 - f1_score: 0.7982 - auc: 0.9622 - dice_coef: 0.7939 - iou: 0.6595
# Epoch 48/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2435 - sensitivity: 0.8674 - specificity: 0.9698 - accuracy: 0.9609 - f1_score: 0.7975 - auc: 0.9626 - dice_coef: 0.7933 - iou: 0.6588
# Epoch 49/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2433 - sensitivity: 0.8679 - specificity: 0.9694 - accuracy: 0.9606 - f1_score: 0.7984 - auc: 0.9627 - dice_coef: 0.7942 - iou: 0.6598
# Epoch 50/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2433 - sensitivity: 0.8683 - specificity: 0.9695 - accuracy: 0.9608 - f1_score: 0.7982 - auc: 0.9625 - dice_coef: 0.7939 - iou: 0.6597
# Epoch 51/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2402 - sensitivity: 0.8714 - specificity: 0.9698 - accuracy: 0.9613 - f1_score: 0.8013 - auc: 0.9635 - dice_coef: 0.7968 - iou: 0.6636
# Epoch 52/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2400 - sensitivity: 0.8715 - specificity: 0.9699 - accuracy: 0.9614 - f1_score: 0.8012 - auc: 0.9634 - dice_coef: 0.7968 - iou: 0.6635
# Epoch 53/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2411 - sensitivity: 0.8697 - specificity: 0.9698 - accuracy: 0.9612 - f1_score: 0.8002 - auc: 0.9632 - dice_coef: 0.7958 - iou: 0.6622
# Epoch 54/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2380 - sensitivity: 0.8732 - specificity: 0.9702 - accuracy: 0.9618 - f1_score: 0.8032 - auc: 0.9639 - dice_coef: 0.7988 - iou: 0.6663
# Epoch 55/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2390 - sensitivity: 0.8724 - specificity: 0.9699 - accuracy: 0.9616 - f1_score: 0.8021 - auc: 0.9638 - dice_coef: 0.7977 - iou: 0.6647
# Epoch 56/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2391 - sensitivity: 0.8730 - specificity: 0.9700 - accuracy: 0.9617 - f1_score: 0.8019 - auc: 0.9639 - dice_coef: 0.7973 - iou: 0.6646
# Epoch 57/80
# 274/274 [==============================] - 53s 189ms/step - loss: 0.2364 - sensitivity: 0.8748 - specificity: 0.9704 - accuracy: 0.9621 - f1_score: 0.8048 - auc: 0.9643 - dice_coef: 0.8003 - iou: 0.6684
# Epoch 58/80
# 274/274 [==============================] - 53s 190ms/step - loss: 0.2339 - sensitivity: 0.8773 - specificity: 0.9705 - accuracy: 0.9625 - f1_score: 0.8073 - auc: 0.9651 - dice_coef: 0.8029 - iou: 0.6719
# Epoch 59/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2345 - sensitivity: 0.8765 - specificity: 0.9706 - accuracy: 0.9625 - f1_score: 0.8070 - auc: 0.9648 - dice_coef: 0.8024 - iou: 0.6713
# Epoch 60/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2334 - sensitivity: 0.8786 - specificity: 0.9705 - accuracy: 0.9626 - f1_score: 0.8073 - auc: 0.9657 - dice_coef: 0.8027 - iou: 0.6717
# Epoch 61/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2509 - sensitivity: 0.8604 - specificity: 0.9690 - accuracy: 0.9595 - f1_score: 0.7918 - auc: 0.9603 - dice_coef: 0.7876 - iou: 0.6515
# Epoch 62/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2382 - sensitivity: 0.8728 - specificity: 0.9702 - accuracy: 0.9618 - f1_score: 0.8030 - auc: 0.9647 - dice_coef: 0.7986 - iou: 0.6661
# Epoch 63/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2343 - sensitivity: 0.8778 - specificity: 0.9705 - accuracy: 0.9624 - f1_score: 0.8067 - auc: 0.9646 - dice_coef: 0.8022 - iou: 0.6709
# Epoch 64/80
# 274/274 [==============================] - 53s 190ms/step - loss: 0.2324 - sensitivity: 0.8789 - specificity: 0.9706 - accuracy: 0.9626 - f1_score: 0.8089 - auc: 0.9654 - dice_coef: 0.8043 - iou: 0.6738
# Epoch 65/80
# 274/274 [==============================] - 52s 190ms/step - loss: 0.2321 - sensitivity: 0.8795 - specificity: 0.9707 - accuracy: 0.9628 - f1_score: 0.8089 - auc: 0.9656 - dice_coef: 0.8043 - iou: 0.6740
# Epoch 66/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2319 - sensitivity: 0.8789 - specificity: 0.9709 - accuracy: 0.9630 - f1_score: 0.8095 - auc: 0.9657 - dice_coef: 0.8049 - iou: 0.6747
# Epoch 67/80
# 274/274 [==============================] - 53s 189ms/step - loss: 0.2324 - sensitivity: 0.8788 - specificity: 0.9708 - accuracy: 0.9629 - f1_score: 0.8086 - auc: 0.9658 - dice_coef: 0.8040 - iou: 0.6736
# Epoch 68/80
# 274/274 [==============================] - 52s 190ms/step - loss: 0.2298 - sensitivity: 0.8813 - specificity: 0.9711 - accuracy: 0.9634 - f1_score: 0.8109 - auc: 0.9664 - dice_coef: 0.8062 - iou: 0.6765
# Epoch 69/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2305 - sensitivity: 0.8807 - specificity: 0.9711 - accuracy: 0.9633 - f1_score: 0.8105 - auc: 0.9658 - dice_coef: 0.8058 - iou: 0.6761
# Epoch 70/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2300 - sensitivity: 0.8808 - specificity: 0.9710 - accuracy: 0.9632 - f1_score: 0.8110 - auc: 0.9662 - dice_coef: 0.8064 - iou: 0.6767
# Epoch 71/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2301 - sensitivity: 0.8813 - specificity: 0.9708 - accuracy: 0.9631 - f1_score: 0.8108 - auc: 0.9661 - dice_coef: 0.8061 - iou: 0.6766
# Epoch 72/80
# 274/274 [==============================] - 53s 190ms/step - loss: 0.2280 - sensitivity: 0.8836 - specificity: 0.9713 - accuracy: 0.9637 - f1_score: 0.8127 - auc: 0.9666 - dice_coef: 0.8080 - iou: 0.6791
# Epoch 73/80
# 274/274 [==============================] - 53s 190ms/step - loss: 0.2286 - sensitivity: 0.8824 - specificity: 0.9712 - accuracy: 0.9636 - f1_score: 0.8124 - auc: 0.9664 - dice_coef: 0.8076 - iou: 0.6786
# Epoch 74/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2286 - sensitivity: 0.8823 - specificity: 0.9714 - accuracy: 0.9637 - f1_score: 0.8123 - auc: 0.9665 - dice_coef: 0.8076 - iou: 0.6785
# Epoch 75/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2274 - sensitivity: 0.8842 - specificity: 0.9712 - accuracy: 0.9637 - f1_score: 0.8131 - auc: 0.9670 - dice_coef: 0.8084 - iou: 0.6797
# Epoch 76/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2285 - sensitivity: 0.8819 - specificity: 0.9713 - accuracy: 0.9636 - f1_score: 0.8130 - auc: 0.9663 - dice_coef: 0.8083 - iou: 0.6794
# Epoch 77/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2272 - sensitivity: 0.8851 - specificity: 0.9710 - accuracy: 0.9636 - f1_score: 0.8135 - auc: 0.9671 - dice_coef: 0.8088 - iou: 0.6800
# Epoch 78/80
# 274/274 [==============================] - 52s 188ms/step - loss: 0.2283 - sensitivity: 0.8838 - specificity: 0.9712 - accuracy: 0.9636 - f1_score: 0.8126 - auc: 0.9666 - dice_coef: 0.8077 - iou: 0.6787
# Epoch 79/80
# 274/274 [==============================] - 53s 190ms/step - loss: 0.2248 - sensitivity: 0.8867 - specificity: 0.9714 - accuracy: 0.9641 - f1_score: 0.8157 - auc: 0.9676 - dice_coef: 0.8109 - iou: 0.6831
# Epoch 80/80
# 274/274 [==============================] - 52s 189ms/step - loss: 0.2246 - sensitivity: 0.8878 - specificity: 0.9713 - accuracy: 0.9640 - f1_score: 0.8162 - auc: 0.9675 - dice_coef: 0.8113 - iou: 0.6836

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

#================= CONSTANTS =================

RESIZE_SIZE = 768   # Full image resize
IMG_SIZE    = 128   # Patch size
OVERLAP     = 0.5   # 50% overlap
THRESHOLD   = 0.5   # Binarization threshold
BATCH_SIZE  = 16    # Mini-batch size for patch prediction

#================= PATCH FUNCTIONS =================

def extract_patches(img, patch_size=IMG_SIZE, overlap=OVERLAP):
    stride = int(patch_size * (1 - overlap))
    H, W = img.shape[:2]
    patches = []
    for y in range(0, H - patch_size + 1, stride):
        for x in range(0, W - patch_size + 1, stride):
            patches.append(img[y:y+patch_size, x:x+patch_size])
    return patches

def stitch_patches(patches, image_size=RESIZE_SIZE, patch_size=IMG_SIZE, overlap=OVERLAP):
    stride = int(patch_size * (1 - overlap))
    stitched_mask = np.zeros((image_size, image_size), dtype=np.float32)
    count_mask = np.zeros((image_size, image_size), dtype=np.float32)

    idx = 0  
    for y in range(0, image_size - patch_size + 1, stride):  
        for x in range(0, image_size - patch_size + 1, stride):  
            stitched_mask[y:y+patch_size, x:x+patch_size] += patches[idx]  
            count_mask[y:y+patch_size, x:x+patch_size] += 1  
            idx += 1  

    stitched_mask /= count_mask  
    return np.clip(stitched_mask, 0, 1)

#================= FULL IMAGE PREDICTION =================

def predict_full_image(model, img_path, batch_size=BATCH_SIZE):
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (RESIZE_SIZE, RESIZE_SIZE))

    patches = extract_patches(img)  
    pred_patches = []  

    # Predict in mini-batches  
    for i in range(0, len(patches), batch_size):  
        batch = np.array([p.astype(np.float32)/255.0 for p in patches[i:i+batch_size]])  
        preds = model.predict(batch, verbose=0)  
        pred_patches.extend([p[:, :, 0] for p in preds])  # remove channel dim  

    full_mask = stitch_patches(pred_patches)  
    return img, full_mask

#================= EVALUATION FUNCTION =================

def evaluate_model(model, image_paths, mask_paths):
    dice_list, iou_list, acc_list, f1_list, sens_list, spec_list = [], [], [], [], [], []

    for img_path, mask_path in zip(image_paths, mask_paths):  
        img, pred_mask = predict_full_image(model, img_path)  

        gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  
        gt_mask = cv2.resize(gt_mask, (RESIZE_SIZE, RESIZE_SIZE)) / 255.0  

        pred_bin = (pred_mask >= THRESHOLD).astype(np.float32)  
        gt_bin   = (gt_mask >= 0.5).astype(np.float32)  

        intersection = np.sum(pred_bin * gt_bin)  
        union = np.sum(pred_bin) + np.sum(gt_bin) - intersection  
        dice = (2 * intersection) / (np.sum(pred_bin) + np.sum(gt_bin) + 1e-7)  
        iou  = intersection / (union + 1e-7)  
        acc  = accuracy_score(gt_bin.flatten(), pred_bin.flatten())  
        f1   = f1_score(gt_bin.flatten(), pred_bin.flatten())  
        sens = recall_score(gt_bin.flatten(), pred_bin.flatten())  
        spec = (np.sum((1 - gt_bin) * (1 - pred_bin)) / np.sum(1 - gt_bin))  

        dice_list.append(dice)  
        iou_list.append(iou)  
        acc_list.append(acc)  
        f1_list.append(f1)  
        sens_list.append(sens)  
        spec_list.append(spec)  

    print(f"Mean Dice        : {np.mean(dice_list):.4f}")  
    print(f"Mean IoU         : {np.mean(iou_list):.4f}")  
    print(f"Mean Accuracy    : {np.mean(acc_list):.4f}")  
    print(f"Mean F1 Score    : {np.mean(f1_list):.4f}")  
    print(f"Mean Sensitivity : {np.mean(sens_list):.4f}")  
    print(f"Mean Specificity : {np.mean(spec_list):.4f}")

#================= VISUALIZATION =================

def visualize_prediction(model, img_path, mask_path):
    img, pred_mask = predict_full_image(model, img_path)
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = cv2.resize(gt_mask, (RESIZE_SIZE, RESIZE_SIZE)) / 255.0

    plt.figure(figsize=(15,5))  
    plt.subplot(1,3,1)  
    plt.imshow(img)  
    plt.title("Input Image")  
    plt.axis("off")  

    plt.subplot(1,3,2)  
    plt.imshow(gt_mask, cmap="gray")  
    plt.title("Ground Truth")  
    plt.axis("off")  

    plt.subplot(1,3,3)  
    plt.imshow(pred_mask, cmap="gray")  
    plt.title("Predicted Mask")  
    plt.axis("off")  

    plt.tight_layout()  
    plt.show()

#================= USAGE =================

# Evaluate all test images
evaluate_model(model, test_images, test_masks)

# Visualize first test image
visualize_prediction(model, test_images[0], test_masks[0])
# Out:
# Mean Dice        : 0.7929
# Mean IoU         : 0.6570
# Mean Accuracy    : 0.9713
# Mean F1 Score    : 0.7929
# Mean Sensitivity : 0.8729
# Mean Specificity : 0.9780

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import csv

# Directories to save predictions, ground truth masks, and original images
PREDICTIONS_DIR = r'C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\trans_unet_512__predicted_mask'
GROUND_TRUTH_DIR = r'C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask'
ORIGINAL_IMAGES_DIR = r'C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images'
os.makedirs(PREDICTIONS_DIR, exist_ok=True)
os.makedirs(GROUND_TRUTH_DIR, exist_ok=True)
os.makedirs(ORIGINAL_IMAGES_DIR, exist_ok=True)

# Constants
THRESHOLD = 0.5
RESIZE_SIZE = 512
CSV_FILE = r"C:\Users\AUSTCSE4090\Desktop\CHASEDB\res_unet_512_metrics.csv"

# Define the function to save predicted masks
def save_predicted_mask(pred_mask, idx):
    mask_bin = (pred_mask > THRESHOLD).astype(np.uint8) * 255  # Binarize
    save_path = os.path.join(PREDICTIONS_DIR, f"predicted_mask_{idx + 1}.png")
    cv2.imwrite(save_path, mask_bin)
    print(f"Saved predicted mask: {save_path}")

# Define the function to save ground truth masks
def save_ground_truth_mask(gt_mask, idx):
    mask_bin = (gt_mask * 255).astype(np.uint8)  # Ensure it is in 0-255 range
    save_path = os.path.join(GROUND_TRUTH_DIR, f"ground_truth_mask_{idx + 1}.png")
    cv2.imwrite(save_path, mask_bin)
    print(f"Saved ground truth mask: {save_path}")

# Define the function to save the original images
def save_original_image(img, idx):
    save_path = os.path.join(ORIGINAL_IMAGES_DIR, f"original_image_{idx + 1}.png")
    img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)  # Convert RGB to BGR for saving with OpenCV
    cv2.imwrite(save_path, img_bgr)
    print(f"Saved original image: {save_path}")

# Function to compute per-image metrics
def compute_metrics_per_image(y_true, y_pred):
    y_true = y_true.astype(np.uint8)
    y_pred = y_pred.astype(np.uint8)

    TP = np.sum((y_true == 1) & (y_pred == 1))
    TN = np.sum((y_true == 0) & (y_pred == 0))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))

    sensitivity = TP / (TP + FN + 1e-6)
    specificity = TN / (TN + FP + 1e-6)
    accuracy = (TP + TN) / (TP + TN + FP + FN + 1e-6)
    precision = TP / (TP + FP + 1e-6)
    f1_score = 2 * precision * sensitivity / (precision + sensitivity + 1e-6)
    dice = 2 * TP / (2 * TP + FP + FN + 1e-6)
    iou = TP / (TP + FP + FN + 1e-6)

    return sensitivity, specificity, accuracy, f1_score, dice, iou

# Initialize CSV file and write header
def initialize_csv():
    with open(CSV_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image_Index", "Sensitivity", "Specificity", "Accuracy", "F1_Score", "Dice", "IoU"])

# Write metrics to CSV
def write_metrics_to_csv(idx, sens, spec, acc, f1, dice, iou):
    with open(CSV_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([idx + 1, sens, spec, acc, f1, dice, iou])
    print(f"Metrics for Image {idx + 1} written to CSV.")

# Modify the visualization function to show original image, ground truth, and predicted mask
def visualize_metrics_and_save_prediction(model, img_path, mask_path, idx):
    # Predict mask for the image
    img, pred_mask = predict_full_image(model, img_path)  # Ensure this function is defined
    
    # Check if the prediction and image are correct
    if img is None or pred_mask is None:
        print(f"Prediction failed for image {img_path}")
        return

    # Read and preprocess the ground truth mask
    gt_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    gt_mask = cv2.resize(gt_mask, (RESIZE_SIZE, RESIZE_SIZE)) / 255.0
    
    # Apply thresholding to both ground truth and predicted masks to ensure they are binary
    gt_mask_bin = (gt_mask >= 0.5).astype(np.uint8)  # Ground truth as binary (0 or 1)
    pred_mask_bin = (pred_mask >= THRESHOLD).astype(np.uint8)  # Predicted mask as binary (0 or 1)
    
    # Compute metrics
    sens, spec, acc, f1, dice, iou = compute_metrics_per_image(gt_mask_bin, pred_mask_bin)
    
    # Print the metrics to verify if they are being calculated correctly
    print(f"Metrics for Image {idx + 1}: Sens: {sens:.3f}, Spec: {spec:.3f}, Acc: {acc:.3f}, F1: {f1:.3f}, Dice: {dice:.3f}, IoU: {iou:.3f}")

    # Plot the original image, ground truth, and predicted mask
    plt.figure(figsize=(18, 6))  # Increase the size to accommodate all 3 images
    
    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Original Image")
    plt.axis("off")
    
    # Ground truth mask
    plt.subplot(1, 3, 2)
    plt.imshow(gt_mask_bin, cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis("off")
    
    # Predicted mask
    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask_bin, cmap='gray')
    plt.title(f"Predicted Mask\nSens: {sens:.3f}, Spec: {spec:.3f}\n"
              f"Acc: {acc:.3f}, F1: {f1:.3f}, Dice: {dice:.3f}, IoU: {iou:.3f}")
    plt.axis("off")
    
    plt.tight_layout()
    plt.show()

    # Save the original image, predicted mask, and ground truth mask
    save_original_image(img, idx)
    save_predicted_mask(pred_mask, idx)
    save_ground_truth_mask(gt_mask, idx)

    # Write the metrics to the CSV file
    write_metrics_to_csv(idx, sens, spec, acc, f1, dice, iou)

# Initialize the CSV file with the header
initialize_csv()

# Example usage: 
for idx, (img_path, mask_path) in enumerate(zip(test_images, test_masks)):
    visualize_metrics_and_save_prediction(model, img_path, mask_path, idx)

print(f"All test image metrics saved to {CSV_FILE}")
# Out:
# Metrics for Image 1: Sens: 0.913, Spec: 0.974, Acc: 0.971, F1: 0.771, Dice: 0.771, IoU: 0.627
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_1.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_1.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_1.png
# Metrics for Image 1 written to CSV.
# Metrics for Image 2: Sens: 0.922, Spec: 0.974, Acc: 0.971, F1: 0.774, Dice: 0.774, IoU: 0.631
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_2.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_2.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_2.png
# Metrics for Image 2 written to CSV.
# Metrics for Image 3: Sens: 0.907, Spec: 0.960, Acc: 0.956, F1: 0.747, Dice: 0.747, IoU: 0.597
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_3.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_3.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_3.png
# Metrics for Image 3 written to CSV.
# Metrics for Image 4: Sens: 0.882, Spec: 0.970, Acc: 0.963, F1: 0.780, Dice: 0.780, IoU: 0.639
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_4.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_4.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_4.png
# Metrics for Image 4 written to CSV.
# Metrics for Image 5: Sens: 0.864, Spec: 0.976, Acc: 0.969, F1: 0.773, Dice: 0.773, IoU: 0.631
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_5.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_5.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_5.png
# Metrics for Image 5 written to CSV.
# Metrics for Image 6: Sens: 0.831, Spec: 0.976, Acc: 0.967, F1: 0.760, Dice: 0.760, IoU: 0.613
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_6.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_6.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_6.png
# Metrics for Image 6 written to CSV.
# Metrics for Image 7: Sens: 0.870, Spec: 0.976, Acc: 0.969, F1: 0.794, Dice: 0.794, IoU: 0.658
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_7.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_7.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_7.png
# Metrics for Image 7 written to CSV.
# Metrics for Image 8: Sens: 0.834, Spec: 0.973, Acc: 0.965, F1: 0.737, Dice: 0.737, IoU: 0.584
# Saved original image: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512original_images\original_image_8.png
# Saved predicted mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512__predicted_mask\predicted_mask_8.png
# Saved ground truth mask: C:\Users\AUSTCSE4090\Desktop\CHASEDB\predicted_mask\res_unet_512_ground_truth_mask\ground_truth_mask_8.png
# Metrics for Image 8 written to CSV.
# All test image metrics saved to C:\Users\AUSTCSE4090\Desktop\CHASEDB\res_unet_512_metrics.csv

# %%
import os

# Define the folder path to save the model
folder_path = r'C:\Users\AUSTCSE4090\Desktop\chasedb\prediction'  # Update this path if needed
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Define the model save path
model_save_path = os.path.join(folder_path, 'res_unet_512_model.h5')

# Save the model in H5 format
model.save(model_save_path)
print(f"Saved model to {model_save_path}")
# Out:
# Saved model to C:\Users\AUSTCSE4090\Desktop\chasedb\prediction\res_unet_512_model.h5

# %%
from tensorflow.keras import backend as K

# Clear any previous models and free memory
K.clear_session()
